# %%
import pandas as pd

products = pd.read_parquet("../data/processed/products_clean.parquet")
behavior = pd.read_parquet("../data/processed/user_behavior_clean.parquet")
users = pd.read_parquet("../data/processed/user_features.parquet")

# %%
import matplotlib.pyplot as plt

products['price'].hist(bins=50)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
products['category'].value_counts().plot(kind='bar')
plt.title("Product Category Distribution")
plt.show()

# %%
behavior['event_type'].value_counts().plot(kind='bar')
plt.title("User Event Distribution")
plt.show()

# %%
behavior['event_type'].value_counts().plot(kind='bar')
plt.title("User Event Distribution")
plt.show()
